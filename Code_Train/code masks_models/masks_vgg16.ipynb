# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
from glob import glob
from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, AveragePooling2D, Dense, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# Set parameters
IMAGE_SIZE = (224, 224)

# %%
train_files = []
mask_files = glob('/content/drive/MyDrive/masks_dataset/*_mask*')
for i in mask_files:
     train_files.append(i.replace('_mask', ''))

# %%
df = pd.DataFrame({"image_path": train_files, "mask_path":mask_files})

def diagnosis(mask_path):
    value = np.max(cv2.imread(mask_path))
    if value:
        return 1
    else:
        return 0

df['mask'] = df["mask_path"].apply(lambda x: diagnosis(x))

# %%
df.head()
# Out:
#                                       image_path  ... mask
# 0  /content/drive/MyDrive/masks_dataset/y549.jpg  ...    1
# 1   /content/drive/MyDrive/masks_dataset/y55.jpg  ...    1
# 2  /content/drive/MyDrive/masks_dataset/y550.jpg  ...    1
# 3  /content/drive/MyDrive/masks_dataset/y551.jpg  ...    1
# 4  /content/drive/MyDrive/masks_dataset/y552.jpg  ...    1
#
# [5 rows x 3 columns]

# %%
df['mask'].value_counts()
# Out:
# 1    1500
# 0    1500
# Name: mask, dtype: int64

# %%
fig, ax = plt.subplots(10,3,figsize=(20,45))
for x in range(10):
    i = random.randint(0, len(df))
    img = cv2.imread(df['image_path'][i])
    mask = cv2.imread(df['mask_path'][i])
    ax[x][0].title.set_text("Brain MRI")
    ax[x][0].imshow(img)
    ax[x][1].title.set_text("Mask - " + str(df['mask'][i]))
    ax[x][1].imshow(mask)
    ax[x][2].title.set_text("Brain MRI with Mask")
    ax[x][2].imshow(img)
    ax[x][2].imshow(mask, alpha=0.4)
plt.tight_layout()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df['mask'] = df['mask'].apply(lambda x: str(x))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image_path  3000 non-null   object
#  1   mask_path   3000 non-null   object
#  2   mask        3000 non-null   object
# dtypes: object(3)
# memory usage: 70.4+ KB

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.15)
df_train, df_val = train_test_split(df_train, test_size=0.15)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)
# Out:
# (2167, 3)
# (383, 3)
# (450, 3)

# %%
datagen = ImageDataGenerator(rescale=1/255.)
train_generator = datagen.flow_from_dataframe(df_train, 
                                             x_col='image_path',
                                             y_col='mask',
                                             class_mode='categorical',
                                             batch_size=32,
                                             shuffle=True,
                                             target_size=IMAGE_SIZE)
validation_generator = datagen.flow_from_dataframe(df_val,
                                                  x_col='image_path',
                                                  y_col='mask',
                                                  class_mode='categorical',
                                                  batch_size=32,
                                                  shuffle=True,
                                                  target_size=IMAGE_SIZE)
test_generator = datagen.flow_from_dataframe(df_test,
                                            x_col='image_path',
                                            y_col='mask',
                                            class_mode='categorical',
                                            batch_size=32,
                                            shuffle=False,
                                            target_size=IMAGE_SIZE)
# Out:
# Found 2167 validated image filenames belonging to 2 classes.
# Found 383 validated image filenames belonging to 2 classes.
# Found 450 validated image filenames belonging to 2 classes.

# %%
from tensorflow.keras.applications.vgg16 import VGG16

base_model = VGG16(weights='imagenet', include_top=False, input_tensor=Input(shape=(224,224,3)))
# for layer in base_model.layers:
#     layer.trainable = False

x = base_model.output
x = AveragePooling2D(pool_size=(4,4))(x)
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(2, activation='softmax')(x)

clf_model_vgg16 = Model(base_model.input, outputs=x)
clf_model_vgg16.compile(loss='categorical_crossentropy',
                 optimizer='adam',
                 metrics=['accuracy'])
clf_model_vgg16.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 14,912,322
# Trainable params: 14,912,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss',
                  mode='min',
                  verbose=1,
                  patience=10)
checkpoint = ModelCheckpoint(filepath='model_vgg16.hdf5',
                            verbose=1,
                            save_best_only=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                             mode='min',
                             verbose=1,
                             patience=5,
                             min_denta=0.0001,
                             factor=0.2)
my_callbacks = [es, checkpoint, reduce_lr]

# %%
history = clf_model_vgg16.fit(train_generator,
                    epochs=30,
                    steps_per_epoch= train_generator.n // train_generator.batch_size,
                    validation_data=validation_generator,
                    validation_steps = validation_generator.n // validation_generator.batch_size,
                    callbacks=[checkpoint, es])
# Out:
# Epoch 1/30
# 67/67 [==============================] - 431s 6s/step - loss: 0.9487 - accuracy: 0.5152 - val_loss: 0.6819 - val_accuracy: 0.6790
#
# Epoch 00001: val_loss improved from inf to 0.68186, saving model to model_vgg16.hdf5
# Epoch 2/30
# 67/67 [==============================] - 52s 779ms/step - loss: 0.6734 - accuracy: 0.6028 - val_loss: 0.6254 - val_accuracy: 0.6506
#
# Epoch 00002: val_loss improved from 0.68186 to 0.62541, saving model to model_vgg16.hdf5
# Epoch 3/30
# 67/67 [==============================] - 52s 779ms/step - loss: 0.5786 - accuracy: 0.6956 - val_loss: 0.6141 - val_accuracy: 0.6619
#
# Epoch 00003: val_loss improved from 0.62541 to 0.61412, saving model to model_vgg16.hdf5
# Epoch 4/30
# 67/67 [==============================] - 52s 778ms/step - loss: 0.5490 - accuracy: 0.7302 - val_loss: 0.5125 - val_accuracy: 0.7784
#
# Epoch 00004: val_loss improved from 0.61412 to 0.51247, saving model to model_vgg16.hdf5
# Epoch 5/30
# 67/67 [==============================] - 52s 775ms/step - loss: 0.5364 - accuracy: 0.7335 - val_loss: 0.5561 - val_accuracy: 0.7102
#
# Epoch 00005: val_loss did not improve from 0.51247
# Epoch 6/30
# 67/67 [==============================] - 52s 778ms/step - loss: 0.5237 - accuracy: 0.7354 - val_loss: 0.4871 - val_accuracy: 0.7898
#
# Epoch 00006: val_loss improved from 0.51247 to 0.48706, saving model to model_vgg16.hdf5
# Epoch 7/30
# 67/67 [==============================] - 52s 775ms/step - loss: 0.5348 - accuracy: 0.7405 - val_loss: 0.5149 - val_accuracy: 0.7585
#
# Epoch 00007: val_loss did not improve from 0.48706
# Epoch 8/30
# 67/67 [==============================] - 52s 774ms/step - loss: 0.5332 - accuracy: 0.7382 - val_loss: 0.4827 - val_accuracy: 0.7585
#
# Epoch 00008: val_loss improved from 0.48706 to 0.48273, saving model to model_vgg16.hdf5
# Epoch 9/30
# 67/67 [==============================] - 52s 779ms/step - loss: 0.4925 - accuracy: 0.7672 - val_loss: 0.4521 - val_accuracy: 0.8267
#
# Epoch 00009: val_loss improved from 0.48273 to 0.45207, saving model to model_vgg16.hdf5
# Epoch 10/30
# 67/67 [==============================] - 52s 776ms/step - loss: 0.4761 - accuracy: 0.7747 - val_loss: 0.4098 - val_accuracy: 0.8352
#
# Epoch 00010: val_loss improved from 0.45207 to 0.40981, saving model to model_vgg16.hdf5
# Epoch 11/30
# 67/67 [==============================] - 52s 776ms/step - loss: 0.4432 - accuracy: 0.7986 - val_loss: 0.3971 - val_accuracy: 0.8210
#
# Epoch 00011: val_loss improved from 0.40981 to 0.39714, saving model to model_vgg16.hdf5
# Epoch 12/30
# 67/67 [==============================] - 52s 775ms/step - loss: 0.4557 - accuracy: 0.7934 - val_loss: 0.4023 - val_accuracy: 0.8097
#
# Epoch 00012: val_loss did not improve from 0.39714
# Epoch 13/30
# 67/67 [==============================] - 52s 777ms/step - loss: 0.3806 - accuracy: 0.8319 - val_loss: 0.3424 - val_accuracy: 0.8523
#
# Epoch 00013: val_loss improved from 0.39714 to 0.34244, saving model to model_vgg16.hdf5
# Epoch 14/30
# 67/67 [==============================] - 52s 775ms/step - loss: 0.4042 - accuracy: 0.8173 - val_loss: 0.3495 - val_accuracy: 0.8551
#
# Epoch 00014: val_loss did not improve from 0.34244
# Epoch 15/30
# 67/67 [==============================] - 52s 773ms/step - loss: 0.3626 - accuracy: 0.8450 - val_loss: 0.3891 - val_accuracy: 0.8438
#
# Epoch 00015: val_loss did not improve from 0.34244
# Epoch 16/30
# 67/67 [==============================] - 52s 776ms/step - loss: 0.3257 - accuracy: 0.8712 - val_loss: 0.3367 - val_accuracy: 0.8920
#
# Epoch 00016: val_loss improved from 0.34244 to 0.33670, saving model to model_vgg16.hdf5
# Epoch 17/30
# 67/67 [==============================] - 52s 772ms/step - loss: 0.3045 - accuracy: 0.8904 - val_loss: 0.3064 - val_accuracy: 0.8807
#
# Epoch 00017: val_loss improved from 0.33670 to 0.30643, saving model to model_vgg16.hdf5
# Epoch 18/30
# 67/67 [==============================] - 52s 772ms/step - loss: 0.2621 - accuracy: 0.8979 - val_loss: 0.3104 - val_accuracy: 0.8864
#
# Epoch 00018: val_loss did not improve from 0.30643
# Epoch 19/30
# 67/67 [==============================] - 52s 772ms/step - loss: 0.2181 - accuracy: 0.9222 - val_loss: 0.2960 - val_accuracy: 0.8693
#
# Epoch 00019: val_loss improved from 0.30643 to 0.29597, saving model to model_vgg16.hdf5
# Epoch 20/30
# 67/67 [==============================] - 52s 772ms/step - loss: 0.1712 - accuracy: 0.9396 - val_loss: 0.3229 - val_accuracy: 0.8722
#
# Epoch 00020: val_loss did not improve from 0.29597
# Epoch 21/30
# 67/67 [==============================] - 52s 771ms/step - loss: 0.1516 - accuracy: 0.9508 - val_loss: 0.2286 - val_accuracy: 0.9290
#
# Epoch 00021: val_loss improved from 0.29597 to 0.22860, saving model to model_vgg16.hdf5
# Epoch 22/30
# 67/67 [==============================] - 52s 771ms/step - loss: 0.1903 - accuracy: 0.9288 - val_loss: 0.2582 - val_accuracy: 0.8977
#
# Epoch 00022: val_loss did not improve from 0.22860
# Epoch 23/30
# 67/67 [==============================] - 52s 772ms/step - loss: 0.2010 - accuracy: 0.9368 - val_loss: 0.2748 - val_accuracy: 0.9148
#
# Epoch 00023: val_loss did not improve from 0.22860
# Epoch 24/30
# 67/67 [==============================] - 52s 775ms/step - loss: 0.1282 - accuracy: 0.9616 - val_loss: 0.3230 - val_accuracy: 0.9062
#
# Epoch 00024: val_loss did not improve from 0.22860
# Epoch 25/30
# 67/67 [==============================] - 52s 775ms/step - loss: 0.1207 - accuracy: 0.9644 - val_loss: 0.2502 - val_accuracy: 0.9091
#
# Epoch 00025: val_loss did not improve from 0.22860
# Epoch 26/30
# 67/67 [==============================] - 52s 775ms/step - loss: 0.0706 - accuracy: 0.9799 - val_loss: 0.2699 - val_accuracy: 0.9205
#
# Epoch 00026: val_loss did not improve from 0.22860
# Epoch 27/30
# 67/67 [==============================] - 52s 773ms/step - loss: 0.1269 - accuracy: 0.9597 - val_loss: 0.2491 - val_accuracy: 0.9148
#
# Epoch 00027: val_loss did not improve from 0.22860
# Epoch 28/30
# 67/67 [==============================] - 52s 774ms/step - loss: 0.0817 - accuracy: 0.9742 - val_loss: 0.2987 - val_accuracy: 0.9006
#
# Epoch 00028: val_loss did not improve from 0.22860
# Epoch 29/30
# 67/67 [==============================] - 52s 773ms/step - loss: 0.1193 - accuracy: 0.9574 - val_loss: 0.2392 - val_accuracy: 0.9261
#
# Epoch 00029: val_loss did not improve from 0.22860
# Epoch 30/30
# 67/67 [==============================] - 52s 773ms/step - loss: 0.0534 - accuracy: 0.9864 - val_loss: 0.2841 - val_accuracy: 0.9290
#
# Epoch 00030: val_loss did not improve from 0.22860

# %%
clf_model_vgg16.save('/content/drive/MyDrive/Soumaya - PFE/masks_models/clf_model_vgg16')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Soumaya - PFE/masks_models/clf_model_vgg16/assets

# %%
clf_model_vgg16.evaluate(test_generator)
# Out:
# 15/15 [==============================] - 75s 5s/step - loss: 0.2788 - accuracy: 0.9133
# [0.2787574231624603, 0.9133333563804626]

# %%
# validate on test set
import seaborn as sns
preds = clf_model_vgg16.predict(test_generator)
preds = np.argmax(preds, axis=1)
labels = np.asarray(df_test['mask']).astype('int')
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(labels, preds)
print("Accuracy: {:.3f}".format(accuracy*100))

cm = confusion_matrix(labels, preds)
report = classification_report(labels, preds, labels=[0,1])
print(report)
plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True)
# Out:
# Accuracy: 91.333
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92       239
#            1       0.89      0.93      0.91       211
#
#     accuracy                           0.91       450
#    macro avg       0.91      0.91      0.91       450
# weighted avg       0.91      0.91      0.91       450

# %%
# load_model_sample.py
from keras.models import load_model
from keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
import os
def load_image(img_path, show=True,img_size=224):
    img = image.load_img(img_path, target_size=(img_size, img_size))
    img_tensor = image.img_to_array(img)                    # (height, width, channels)
    img_tensor = np.expand_dims(img_tensor, axis=0)         # (1, height, width, channels), add a dimension because the model expects this shape: (batch_size, height, width, channels)
    img_tensor /= 255.                                      # imshow expects values in the range [0, 1]
    if show:
        plt.imshow(img_tensor[0])                           
        plt.axis('off')
        plt.show()
    return img_tensor

# %%
img_path = '/content/no0.jpg'   
new_image = load_image(img_path)
pred = clf_model_vgg16.predict(new_image)
preds = np.argmax(pred, axis=1)
print('Modèle: VGG16 avec mask')
if(preds[0]<0.5):
  print("**No tumor detected***")
  print("Accucracy:",round(pred[0][0]*100,5),"%")
else:
  print("***Tumor detected***")
  print("Accucracy:",round(pred[0][1]*100,5),"%")
# Out:
# Modèle: VGG16 avec mask
# **No tumor detected***
# Accucracy: 99.89688 %
