# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
import os
import random
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

import cv2
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# DataPath = "/content/drive/MyDrive/Colab Notebooks/code brain tumor /masks_dataset"
DataPath = "/content/drive/MyDrive/masks_dataset"

dirs = []
images = []
masks = []
for dirname, _, filenames in os.walk(DataPath):
    for filename in filenames:
        if 'mask'in filename:
            dirs.append(dirname.replace(DataPath, ''))
            masks.append(filename)
            images.append(filename.replace('_mask', ''))

# %%
list = os.listdir("/content/drive/MyDrive/masks_dataset") # dir is your directory path
number_files = len(list)
print (number_files)
# Out:
# 6000

# %%
len(dirs), len(images), len(masks)
# Out:
# (3000, 3000, 3000)

# %%
imagePath_df = pd.DataFrame({'directory':dirs, 'images': images, 'masks': masks})

# %%
imagePath_df.head()
# Out:
#   directory      images            masks
# 0             no471.jpg   no471_mask.jpg
# 1              no89.jpg    no89_mask.jpg
# 2             y1323.jpg   y1323_mask.jpg
# 3            no1033.jpg  no1033_mask.jpg
# 4             y1353.jpg   y1353_mask.jpg

# %%
def print_imShape():
  
  idx = np.random.randint(0, len(imagePath_df))
    
  imagePath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['images'].iloc[idx])
  maskPath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['masks'].iloc[idx])
    
  image = cv2.imread(imagePath)
  mask = cv2.imread(maskPath)
    
  print(image.shape, mask.shape)

# %%
def plot_images():
    idx = np.random.randint(0, len(imagePath_df))
    
    imagePath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['images'].iloc[idx])
    maskPath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['masks'].iloc[idx])
    
    image = cv2.imread(imagePath)
    mask = cv2.imread(maskPath)
    
    fig, axs = plt.subplots(1,3, figsize=[13,15])
    
    axs[0].imshow(image)
    axs[0].set_title('Brain MRI')
    
    axs[1].imshow(mask)
    axs[1].set_title('Mask')
    
    axs[2].imshow(image)
    axs[2].imshow(mask, alpha=0.3)
    axs[2].set_title('MRI with mask')
    
    plt.grid(False)
    plt.show()

# %%
for i in range(5):
    plot_images()

# %%
imagePath_df['image-path'] = DataPath + imagePath_df['directory'] + '/' + imagePath_df['images']
imagePath_df['mask-path'] = DataPath + imagePath_df['directory'] + '/' + imagePath_df['masks']

# %%
train , test = train_test_split(imagePath_df, test_size=0.25, random_state=21)

# %%
EPOCHS = 35
BATCH_SIZE = 32
ImgHieght = 256
ImgWidth = 256
Channels = 3

# %%
data_augmentation = dict(rotation_range=0.2,
                        width_shift_range=0.05,
                        height_shift_range=0.05,
                        shear_range=0.05,
                        zoom_range=0.05,
                        horizontal_flip=True,
                        fill_mode='nearest')

# %%
# image generator
imagegen = ImageDataGenerator(rescale=1./255., **data_augmentation)
maskgen = ImageDataGenerator(rescale=1./255., **data_augmentation)


# train generator
timage_generator=imagegen.flow_from_dataframe(dataframe=train,
                                            x_col="image-path",
                                            batch_size= BATCH_SIZE,
                                            seed=42,
                                            class_mode=None,
                                            target_size=(ImgHieght,ImgWidth),
                                            color_mode='rgb')
# validation data generator
tmask_generator=maskgen.flow_from_dataframe(dataframe=train,
                                            x_col="mask-path",
                                            batch_size=BATCH_SIZE,
                                            seed=42,
                                            class_mode=None,
                                            target_size=(ImgHieght,ImgWidth),
                                            color_mode='grayscale')
# Out:
# Found 2250 validated image filenames.
# Found 2250 validated image filenames.

# %%
# image generator
imagegen = ImageDataGenerator(rescale=1./255.)
maskgen = ImageDataGenerator(rescale=1./255.)


# train generator
vimage_generator=imagegen.flow_from_dataframe(dataframe=test[1:10],
                                            x_col="image-path",
                                            batch_size= BATCH_SIZE,
                                            seed=42,
                                            class_mode=None,
                                            target_size=(ImgHieght,ImgWidth),
                                            color_mode='rgb')
# validation data generator
vmask_generator=maskgen.flow_from_dataframe(dataframe=test[1:10],
                                            x_col="mask-path",
                                            batch_size=BATCH_SIZE,
                                            seed=42,
                                            class_mode=None,
                                            target_size=(ImgHieght,ImgWidth),
                                            color_mode='grayscale')
# Out:
# Found 9 validated image filenames.
# Found 9 validated image filenames.

# %%
def data_iterator(image_gen, mask_gen):
    for img, mask in zip(image_gen, mask_gen):
        yield img, mask

# %%
train_gen = data_iterator(timage_generator, tmask_generator)
valid_gen = data_iterator(vimage_generator, vmask_generator)

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x

# %%
def get_unet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    """Function to define the UNET Model"""
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
input_img = Input((ImgHieght, ImgWidth, 3), name='img')
model1 = get_unet(input_img, n_filters=16, dropout=0.2, batchnorm=True)
model1.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])

# %%
model1.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 448         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 16) 0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 4640        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 32) 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 32) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 32)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 64)   0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 128)  0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 256)  295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 256)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 128)  295040      activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 256)  0           conv2d_transpose[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 256)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 128)  295040      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 64)   73792       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 64, 128)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 64)   73792       dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 32) 18464       activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128, 128, 64) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 32) 18464       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 128, 32) 128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 128, 32) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 16) 4624        activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 32) 0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256, 256, 32) 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 16) 4624        dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 256, 256, 16) 64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 256, 256, 16) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  17          activation_17[0][0]
# ==================================================================================================
# Total params: 1,179,409
# Trainable params: 1,177,937
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=1e-5, verbose=1),
    ModelCheckpoint('/content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
STEP_SIZE_TRAIN = timage_generator.n/BATCH_SIZE
STEP_SIZE_VALID = vimage_generator.n/BATCH_SIZE

# %%
results = model1.fit(train_gen,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    callbacks=callbacks,
                    validation_data=valid_gen,
                   validation_steps=STEP_SIZE_VALID)
# Out:
# Epoch 1/35
# 70/70 [==============================] - 3705s 53s/step - loss: 0.4798 - accuracy: 0.8680 - val_loss: 0.6076 - val_accuracy: 0.6691
#
# Epoch 00001: val_loss improved from inf to 0.60759, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 2/35
# 70/70 [==============================] - 69s 983ms/step - loss: 0.2684 - accuracy: 0.9669 - val_loss: 0.3681 - val_accuracy: 0.9043
#
# Epoch 00002: val_loss improved from 0.60759 to 0.36814, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 3/35
# 70/70 [==============================] - 68s 979ms/step - loss: 0.1861 - accuracy: 0.9700 - val_loss: 0.2207 - val_accuracy: 0.9662
#
# Epoch 00003: val_loss improved from 0.36814 to 0.22068, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 4/35
# 70/70 [==============================] - 67s 955ms/step - loss: 0.1419 - accuracy: 0.9693 - val_loss: 0.1502 - val_accuracy: 0.9748
#
# Epoch 00004: val_loss improved from 0.22068 to 0.15019, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 5/35
# 70/70 [==============================] - 68s 970ms/step - loss: 0.1308 - accuracy: 0.9659 - val_loss: 0.1444 - val_accuracy: 0.9720
#
# Epoch 00005: val_loss improved from 0.15019 to 0.14441, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 6/35
# 70/70 [==============================] - 67s 958ms/step - loss: 0.1000 - accuracy: 0.9699 - val_loss: 0.0899 - val_accuracy: 0.9781
#
# Epoch 00006: val_loss improved from 0.14441 to 0.08992, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 7/35
# 70/70 [==============================] - 66s 939ms/step - loss: 0.0811 - accuracy: 0.9728 - val_loss: 0.0820 - val_accuracy: 0.9764
#
# Epoch 00007: val_loss improved from 0.08992 to 0.08200, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 8/35
# 70/70 [==============================] - 65s 937ms/step - loss: 0.1187 - accuracy: 0.9656 - val_loss: 0.1147 - val_accuracy: 0.9713
#
# Epoch 00008: val_loss did not improve from 0.08200
# Epoch 9/35
# 70/70 [==============================] - 65s 937ms/step - loss: 0.0841 - accuracy: 0.9697 - val_loss: 0.0744 - val_accuracy: 0.9751
#
# Epoch 00009: val_loss improved from 0.08200 to 0.07443, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 10/35
# 70/70 [==============================] - 65s 936ms/step - loss: 0.1143 - accuracy: 0.9647 - val_loss: 0.0921 - val_accuracy: 0.9742
#
# Epoch 00010: val_loss did not improve from 0.07443
# Epoch 11/35
# 70/70 [==============================] - 65s 927ms/step - loss: 0.0709 - accuracy: 0.9689 - val_loss: 0.0797 - val_accuracy: 0.9735
#
# Epoch 00011: val_loss did not improve from 0.07443
# Epoch 12/35
# 70/70 [==============================] - 65s 930ms/step - loss: 0.0572 - accuracy: 0.9752 - val_loss: 0.0636 - val_accuracy: 0.9782
#
# Epoch 00012: val_loss improved from 0.07443 to 0.06359, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 13/35
# 70/70 [==============================] - 64s 915ms/step - loss: 0.0519 - accuracy: 0.9760 - val_loss: 0.0524 - val_accuracy: 0.9823
#
# Epoch 00013: val_loss improved from 0.06359 to 0.05244, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 14/35
# 70/70 [==============================] - 64s 914ms/step - loss: 0.0482 - accuracy: 0.9765 - val_loss: 0.0450 - val_accuracy: 0.9843
#
# Epoch 00014: val_loss improved from 0.05244 to 0.04501, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 15/35
# 70/70 [==============================] - 65s 930ms/step - loss: 0.0451 - accuracy: 0.9773 - val_loss: 0.0500 - val_accuracy: 0.9812
#
# Epoch 00015: val_loss did not improve from 0.04501
# Epoch 16/35
# 70/70 [==============================] - 68s 976ms/step - loss: 0.0411 - accuracy: 0.9781 - val_loss: 0.0434 - val_accuracy: 0.9839
#
# Epoch 00016: val_loss improved from 0.04501 to 0.04344, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 17/35
# 70/70 [==============================] - 69s 984ms/step - loss: 0.0385 - accuracy: 0.9787 - val_loss: 0.0460 - val_accuracy: 0.9827
#
# Epoch 00017: val_loss did not improve from 0.04344
# Epoch 18/35
# 70/70 [==============================] - 68s 980ms/step - loss: 0.0374 - accuracy: 0.9789 - val_loss: 0.0424 - val_accuracy: 0.9833
#
# Epoch 00018: val_loss improved from 0.04344 to 0.04243, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 19/35
# 70/70 [==============================] - 68s 978ms/step - loss: 0.0343 - accuracy: 0.9795 - val_loss: 0.0424 - val_accuracy: 0.9842
#
# Epoch 00019: val_loss improved from 0.04243 to 0.04241, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 20/35
# 70/70 [==============================] - 69s 989ms/step - loss: 0.0337 - accuracy: 0.9798 - val_loss: 0.0439 - val_accuracy: 0.9827
#
# Epoch 00020: val_loss did not improve from 0.04241
# Epoch 21/35
# 70/70 [==============================] - 69s 985ms/step - loss: 0.0314 - accuracy: 0.9803 - val_loss: 0.0447 - val_accuracy: 0.9838
#
# Epoch 00021: val_loss did not improve from 0.04241
# Epoch 22/35
# 70/70 [==============================] - 68s 982ms/step - loss: 0.0320 - accuracy: 0.9798 - val_loss: 0.0497 - val_accuracy: 0.9820
#
# Epoch 00022: val_loss did not improve from 0.04241
# Epoch 23/35
# 70/70 [==============================] - 69s 985ms/step - loss: 0.0295 - accuracy: 0.9806 - val_loss: 0.0399 - val_accuracy: 0.9836
#
# Epoch 00023: val_loss improved from 0.04241 to 0.03987, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 24/35
# 70/70 [==============================] - 68s 977ms/step - loss: 0.0303 - accuracy: 0.9803 - val_loss: 0.0329 - val_accuracy: 0.9849
#
# Epoch 00024: val_loss improved from 0.03987 to 0.03285, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 25/35
# 70/70 [==============================] - 68s 978ms/step - loss: 0.0294 - accuracy: 0.9805 - val_loss: 0.0356 - val_accuracy: 0.9853
#
# Epoch 00025: val_loss did not improve from 0.03285
# Epoch 26/35
# 70/70 [==============================] - 67s 960ms/step - loss: 0.0272 - accuracy: 0.9811 - val_loss: 0.0407 - val_accuracy: 0.9842
#
# Epoch 00026: val_loss did not improve from 0.03285
# Epoch 27/35
# 70/70 [==============================] - 66s 949ms/step - loss: 0.0254 - accuracy: 0.9816 - val_loss: 0.0423 - val_accuracy: 0.9843
#
# Epoch 00027: val_loss did not improve from 0.03285
# Epoch 28/35
# 70/70 [==============================] - 65s 937ms/step - loss: 0.0258 - accuracy: 0.9815 - val_loss: 0.0435 - val_accuracy: 0.9831
#
# Epoch 00028: val_loss did not improve from 0.03285
# Epoch 29/35
# 70/70 [==============================] - 65s 928ms/step - loss: 0.0281 - accuracy: 0.9808 - val_loss: 0.0318 - val_accuracy: 0.9865
#
# Epoch 00029: val_loss improved from 0.03285 to 0.03179, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 30/35
# 70/70 [==============================] - 65s 930ms/step - loss: 0.0237 - accuracy: 0.9819 - val_loss: 0.0317 - val_accuracy: 0.9860
#
# Epoch 00030: val_loss improved from 0.03179 to 0.03168, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 31/35
# 70/70 [==============================] - 67s 953ms/step - loss: 0.0240 - accuracy: 0.9820 - val_loss: 0.0301 - val_accuracy: 0.9872
#
# Epoch 00031: val_loss improved from 0.03168 to 0.03011, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 32/35
# 70/70 [==============================] - 68s 974ms/step - loss: 0.0236 - accuracy: 0.9819 - val_loss: 0.0252 - val_accuracy: 0.9884
#
# Epoch 00032: val_loss improved from 0.03011 to 0.02523, saving model to /content/drive/MyDrive/Soumaya - PFE/unet/model-brain-mri.h5
# Epoch 33/35
# 70/70 [==============================] - 66s 944ms/step - loss: 0.0230 - accuracy: 0.9822 - val_loss: 0.0294 - val_accuracy: 0.9870
#
# Epoch 00033: val_loss did not improve from 0.02523
# Epoch 34/35
# 70/70 [==============================] - 66s 942ms/step - loss: 0.0219 - accuracy: 0.9825 - val_loss: 0.0351 - val_accuracy: 0.9841
#
# Epoch 00034: val_loss did not improve from 0.02523
# Epoch 35/35
# 70/70 [==============================] - 66s 940ms/step - loss: 0.0217 - accuracy: 0.9824 - val_loss: 0.0294 - val_accuracy: 0.9866
#
# Epoch 00035: val_loss did not improve from 0.02523

# %%
# load the best model
model1.save('/content/drive/MyDrive/Soumaya - PFE/unet/saved_unet')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/saved_unet/assets

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss", color=sns.xkcd_rgb['greenish teal'])
plt.plot(results.history["val_loss"], label="val_loss", color=sns.xkcd_rgb['amber'])
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend()
# plt.grid(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-0682fa3d0443> in <module>()
#       1 plt.figure(figsize=(8, 8))
#       2 plt.title("Learning curve")
# ----> 3 plt.plot(results.history["loss"], label="loss", color=sns.xkcd_rgb['greenish teal'])
#       4 plt.plot(results.history["val_loss"], label="val_loss", color=sns.xkcd_rgb['amber'])
#       5 plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
#
# NameError: name 'results' is not defined

# %%
acc = results.history['accuracy']
val_acc = results.history['val_accuracy']

loss = results.history['loss']
val_loss = results.history['val_loss']

epochs_range = range(31)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import tensorflow

# %%
model=tensorflow.keras.models.load_model("/content/drive/MyDrive/Soumaya - PFE/unet/saved_unet")

# %%
eval_results = model.evaluate(valid_gen, steps=STEP_SIZE_VALID, verbose=1)
# Out:
# 23/23 [==============================] - 3s 88ms/step - loss: 0.0145 - accuracy: 0.9928

# %%
for i in range(10):
    idx = np.random.randint(0, len(imagePath_df))
    
    imagePath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['images'].iloc[idx])
    maskPath = os.path.join(DataPath, imagePath_df['directory'].iloc[idx], imagePath_df['masks'].iloc[idx])
    
    image = cv2.imread(imagePath)
    mask = cv2.imread(maskPath)
    
    img = cv2.resize(image ,(ImgHieght, ImgWidth))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model1.predict(img)
   
    plt.figure(figsize=(12,12))
    plt.subplot(1,4,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,4,2)
    plt.imshow(mask)
    plt.title('Original Mask')
    plt.subplot(1,4,3)
    plt.imshow(np.squeeze(pred))
    plt.title('Prediction')
    plt.subplot(1,4,4)
    plt.imshow(np.squeeze(pred) > 0.5)
    plt.title('BinaryPrediction')
    plt.show()

# %%
prob_pred = model.predict(valid_gen)
from sklearn import metrics
print('Accuracy score is :', np.round(metrics.accuracy_score(valid_gen, pred),4))
print('Precision score is :', np.round(metrics.precision_score(valid_gen, pred, average='weighted'),4))
print('Recall score is :', np.round(metrics.recall_score(valid_gen, pred, average='weighted'),4))
print('F1 Score is :', np.round(metrics.f1_score(valid_gen, pred, average='weighted'),4))
print('ROC AUC Score is :', np.round(metrics.roc_auc_score(valid_gen, pred,multi_class='ovo', average='weighted'),4))
print('Cohen Kappa Score:', np.round(metrics.cohen_kappa_score(valid_gen, pred),4))

print('\t\tClassification Report:\n', metrics.classification_report(valid_gen, prob_pred))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-26bff3b8fa80> in <module>()
#       1 # prob_pred = model.predict(valid_gen)
#       2 from sklearn import metrics
# ----> 3 print('Accuracy score is :', np.round(metrics.accuracy_score(valid_gen, pred),4))
#       4 print('Precision score is :', np.round(metrics.precision_score(valid_gen, pred, average='weighted'),4))
#       5 print('Recall score is :', np.round(metrics.recall_score(valid_gen, pred, average='weighted'),4))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     183
#     184     # Compute accuracy for each possible representation
# --> 185     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     186     check_consistent_length(y_true, y_pred, sample_weight)
#     187     if y_type.startswith('multilabel'):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      78     y_pred : array or indicator matrix
#      79     """
# ---> 80     check_consistent_length(y_true, y_pred)
#      81     type_true = type_of_target(y_true)
#      82     type_pred = type_of_target(y_pred)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     206     """
#     207
# --> 208     lengths = [_num_samples(X) for X in arrays if X is not None]
#     209     uniques = np.unique(lengths)
#     210     if len(uniques) > 1:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in <listcomp>(.0)
#     206     """
#     207
# --> 208     lengths = [_num_samples(X) for X in arrays if X is not None]
#     209     uniques = np.unique(lengths)
#     210     if len(uniques) > 1:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _num_samples(x)
#     145             x = np.asarray(x)
#     146         else:
# --> 147             raise TypeError(message)
#     148
#     149     if hasattr(x, 'shape') and x.shape is not None:
#
# TypeError: Expected sequence or array-like, got <class 'generator'>

# %%
# validate on test set
predictions = model.predict(X_test_prep)
predictions = [1 if x>0.5 else 0 for x in predictions]

accuracy = accuracy_score(y_test, predictions)
print('Test Accuracy = %.2f' % accuracy)

confusion_mtx = confusion_matrix(y_test, predictions) 
cm = plot_confusion_matrix(confusion_mtx, classes = list(labels.items()), normalize=False)

# %%
import glob
# %cd /content/drive/MyDrive
liste_fichiers = glob.glob("*_mask.jpg")
for i in liste_fichiers:
  path="/content/drive/MyDrive/"+i
  os.remove(path)
